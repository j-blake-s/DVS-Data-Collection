# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with np.load("ASL-Signs.npz") as data:
  trainX = data['tX']
  trainY = data['tY']
  valX = data['vX']
  valY = data['vY']

# %%
idx=4
plt.figure()
plt.imshow(np.sum(trainX[idx,0,:,:,:], axis=-1))
print(trainY[idx])
# Out:
# 1.0

# %%
idx=3
plt.figure()
plt.imshow(torch.sum(out[idx,0,:,:,:], axis=-1))
print(trainY[idx])
print(out[idx].shape)
# Out:
# [2.]
# torch.Size([2, 240, 320, 75])
