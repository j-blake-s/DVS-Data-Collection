# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with np.load("../ASL-Signs.npz") as data:
  trainX = data['tX']
  trainY = data['tY']
  valX = data['vX']
  valY = data['vY']

print(trainX.shape)
print(valX.shape)
# Out:
# (19, 2, 240, 320, 45)
# (5, 2, 240, 320, 45)

# %%
idx=4
plt.figure()
plt.imshow(np.sum(valX[idx,0,:,:,:], axis=-1))
print(trainY[idx])
# Out:
# 4.0
